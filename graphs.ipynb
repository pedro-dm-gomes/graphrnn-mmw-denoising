# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

import matplotlib.pyplot as plt
import numpy as np
import json
import os
import pandas as pd

base_path = './experiments/'

# load 'history.csv' file from experiments/ subdirectory
def load_history(experiment_dir):
    print("Loading ", experiment_dir)
    history_path = os.path.join(experiment_dir, 'history0.csv')
    return pd.read_csv(history_path)

# load subdirectories from base_path in a list
def load_experiments(base_path):
    experiments = []
    for experiment in sorted(os.listdir(base_path)):
        if os.path.isdir(os.path.join(base_path, experiment)):
            experiments.append(experiment)
    return experiments

# %%
experiments = load_experiments(base_path)
print(list(enumerate(experiments)))
history = load_history(os.path.join(base_path, experiments[50]))
# Out:
# [(0, 'manual_test_0'), (1, 'manual_test_01'), (2, 'manual_test_02'), (3, 'manual_test_03'), (4, 'manual_test_04'), (5, 'manual_test_05'), (6, 'manual_test_06'), (7, 'manual_test_07'), (8, 'manual_test_08'), (9, 'manual_test_09'), (10, 'manual_test_10'), (11, 'manual_test_11'), (12, 'manual_test_12'), (13, 'manual_test_double_tnet_00'), (14, 'manual_test_double_tnet_01'), (15, 'manual_test_double_tnet_02'), (16, 'manual_test_double_tnet_03'), (17, 'manual_test_double_tnet_04'), (18, 'manual_test_double_tnet_05'), (19, 'manual_test_double_tnet_06'), (20, 'manual_test_double_tnet_07'), (21, 'manual_test_init_dense_00'), (22, 'manual_test_init_dense_01_relu'), (23, 'manual_test_init_dense_02_relu'), (24, 'manual_test_init_dense_02b_relu'), (25, 'manual_test_init_dense_03_relu'), (26, 'manual_test_init_dense_04_relu'), (27, 'manual_test_intensity_00'), (28, 'manual_test_intensity_01'), (29, 'manual_test_intensity_02'), (30, 'manual_test_intensity_03'), (31, 'manual_test_intensity_04'), (3
# ...

# %%
# plot training and validation loss in a (16,9) figure
plt.figure(figsize=(16,9))
plt.plot(history['loss'], label='loss')
plt.plot(history['val_loss'], label='val_loss')
plt.legend()

# %%
# %matplotlib inline
# plot training and validation accuracy in a (16,9) figure
# acc_metric = 'sparse_categorical_accuracy'
acc_metric = 'custom_metric'
plt.close()
plt.figure(figsize=(16,9))
plt.plot(history[acc_metric], label='acc')
# plt.plot(history[str('val_'+acc_metric)], label='val_acc')
# plt.legend()
# plt.show()
print(history[str('val_'+acc_metric)].shape)
# Out:
# (1252,)
# Error in callback <function flush_figures at 0x7f89fe8271f0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:121, in flush_figures()
#     118 if InlineBackend.instance().close_figures:
#     119     # ignore the tracking, just draw and close all figures
#     120     try:
# --> 121         return show(True)
#     122     except Exception as e:
#     123         # safely show traceback if in IPython, else raise
#     124         ip = get_ipython()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:41, in show(close, block)
#      39 try:
#      40     for figure_manager in Gcf.get_all_fig_managers():
# ---> 41         display(
#      42             figure_manager.canvas.figure,
# ...
